# %%
import sys, os
sys.path.append(os.path.abspath("C:\\Users\\dsolg\\Documents\\Projects\\nba-trade-eval"))
sys.path.append(os.path.abspath("C:\\Users\\dsolg\\Documents\\Projects\\nba-trade-eval\\src"))

# %%
data["points"].plot(kind="bar")
plt.show()

# %%
data = pd.DataFrame({"player": ["A", "B", "C"], "points": [10, 15, 20]})
data
# Out:
#   player  points
# 0      A      10
# 1      B      15
# 2      C      20

# %%
from src.data_structures import PlayerSnapshot, InjuryHistory, Contract, TeamSnapshot

player = PlayerSnapshot(
    player_id = "123",
    age = 28,
    basic_stats = {"pts": 25, "reb": 8},
    advanced_stats = {"bpm": 3.2},
    position_vector=[0, 1, 0, 0, 0],
    skill_vector = [0.8, 0.6, 0.3],
    usage_profile = {"on_ball": 0.7, "off_ball": 0.3}
)

player
# Out:
# PlayerSnapshot(player_id=123, age=28)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import torch
